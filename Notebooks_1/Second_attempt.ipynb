# %% [markdown]
# # Connect Colab to Google Drive

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024-2025] AN2DL/Homework 1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/[2024-2025] AN2DL/Homework 1

# %% [markdown]
# # Import Libraries

# %%
# %%writefile requirements.txt
# tensorflow==2.17.0
# keras==3.4.1
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Collecting tensorflow==2.17.0 (from -r requirements.txt (line 1))
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting keras==3.4.1 (from -r requirements.txt (line 2))
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.67.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1->-r requirements.txt (line 2)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras==3.4.1->-r requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.45.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.4.1->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.4.1->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.4.1->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.0.2)
# Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.1 MB/s eta 0:00:00
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.5 MB/s eta 0:00:00
# Installing collected packages: keras, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# Successfully installed keras-3.4.1 tensorflow-2.17.0

# %%
# !pip install keras-cv
import keras_cv
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 8.7 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 36.6 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %%
import numpy as np
import os
import shutil
import tensorflow as tf
import keras as tfk
from keras import layers as tfkl
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

seed = 42

# %% [markdown]
# ## Help Functions

# %%
def plot_images(images, num=9):
    plt.figure(figsize=(8, 8))
    for i in range(num):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        plt.axis("off")
    plt.tight_layout()
    plt.show()

def plot_confusion_matrix(model, X_test, y_test):
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)
    if y_test.ndim > 1:
        y_test = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(len(cm)))
    disp.plot(cmap='viridis', xticks_rotation='vertical')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# # Load the Data

# %%
#Load the dataset from the .npz file and take "images" and "labels"
data = np.load('training_set_without_outlier.npz')
images = data['images']
labels = data['labels']

#Initial shuffle of the data
indices = np.random.permutation(len(images))
shuffled_images = images[indices]
shuffled_labels = labels[indices]

#Free some memory
del data
del images
del labels
del indices

# %% [markdown]
# # Process Data

# %%
#Normalization of images and categorical format for labels
normalized_images = shuffled_images / 255.0
categorical_labels = to_categorical(shuffled_labels).astype('float32')

# %%
# Split data into Training set and Validation set
X_train, X_val, y_train, y_val = train_test_split(normalized_images, categorical_labels, test_size=0.2, stratify=categorical_labels)

print("Training set shape:", X_train.shape)
print("Validation set shape:", X_val.shape)
print("Training labels shape:", y_train.shape)
print("Validation labels shape:", y_val.shape)
# Out:
# Training set shape: (9567, 96, 96, 3)
# Validation set shape: (2392, 96, 96, 3)
# Training labels shape: (9567, 8)
# Validation labels shape: (2392, 8)

# %% [markdown]
# # Augmentation

# %%
#First we plot the first 9 images of the dataset, to have a look at them
plot_images(normalized_images, num=9)
# Out:
# Prime 9 immagini originali:

# %%
#Through Keras_cv we define a random pipeline of augmentations
data_augmentation = keras_cv.layers.RandomAugmentationPipeline(
    layers=[
        keras_cv.layers.RandomContrast(factor=0.8, value_range=(0.0, 1.0), seed=seed),
        keras_cv.layers.RandomHue(factor=(0.8,1.0), value_range=(0.0, 1.0), seed=seed),
        keras_cv.layers.RandomSharpness(factor = 1, value_range=(0.0, 1.0), seed=seed),
        keras_cv.layers.RandomTranslation(height_factor=0.5, width_factor=0.5, seed=seed),
        keras_cv.layers.RandomColorDegeneration(factor = 1, seed=seed),
        keras_cv.layers.RandomChannelShift(factor=0.8, value_range=(0.0, 1.0), channels=3, seed=seed)
    ],
    seed=seed,
    augmentations_per_image=1
)


# Test the augmentation just on the first 9 images
augmented_images = data_augmentation(normalized_images[:9])

#The augmentation layer transforms the input into a tensor, here we just convert it into numpy
augmented_images = augmented_images.numpy()

#Plot augmented images
plot_images(augmented_images, num=9)

# %%
X_train = data_augmentation(X_train)
X_val = data_augmentation(X_val)

# %%
# Convert the Training set and Validation set into an appropriate format for the CutMix and Mixup transformations.
# Indeed the images and labels need to be coupled for such transformation
batch_size = 32  # Adjust as needed
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size)

# Define the CutMix and Mixup augmentations
cutmix = keras_cv.layers.CutMix(seed=seed)
mixup = keras_cv.layers.MixUp(seed=seed)

# Define a function to apply CutMix or MixUp (manually modified)
def apply_advanced_augmentation(images, labels):
    return cutmix({"images": images, "labels": labels})

# Apply advanced augmentation to the train dataset
train_dataset = train_dataset.map(lambda x, y: apply_advanced_augmentation(x, y))
val_dataset = val_dataset.map(lambda x, y: apply_advanced_augmentation(x, y))

# %%
# Reconvert the Training and Validation set into numpy arrays
X_train, y_train = [], []
for batch in train_dataset:
    images = batch["images"].numpy()
    labels = batch["labels"].numpy()
    X_train.append(images)
    y_train.append(labels)
X_train = np.concatenate(X_train, axis=0)
y_train = np.concatenate(y_train, axis=0)

X_val, y_val = [], []
for batch in val_dataset:
    images = batch["images"].numpy()
    labels = batch["labels"].numpy()
    X_val.append(images)
    y_val.append(labels)
X_val = np.concatenate(X_val, axis=0)
y_val = np.concatenate(y_val, axis=0)

# %%
#Additional plot of final result of images
plot_images(X_train, num=9)

# %% [markdown]
# ```
# # Questo è formattato come codice
# ```
#
# # Define Models

# %%
input_shape = (96, 96, 3)
output_shape = 8
learning_rate = 0.001
batch_size = 64
epochs = 300

def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=learning_rate,
    name = "Simple_CNN"
):

    input_layer = tfkl.Input(shape=input_shape, name='Input')

    if name == "Simple_CNN":
      """Builds a simple CNN composed by Conv2D, Activations, Pooling and Dense layers"""

      x = tfkl.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(input_layer)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=2, strides=2)(x)

      x = tfkl.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=2, strides=2)(x)

      x = tfkl.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='he_uniform')(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)

      x = tfkl.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation='relu', kernel_initializer='he_uniform')(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)

      x = tfkl.GlobalAveragePooling2D()(x)

      x = tfkl.Dense(units=128, activation='relu', kernel_initializer='he_uniform')(x)
      x = tfkl.Activation('relu')(x)
      output_layer = tfkl.Dense(units=output_shape, activation='softmax', kernel_initializer='he_uniform', name='Output')(x)

      model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

      loss = tfk.losses.CategoricalCrossentropy()
      optimizer = tfk.optimizers.Adam(learning_rate)
      metrics = ['accuracy']
      model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

      return model

    elif name == "Normalized_Regularized_CNN":
      """Builds CNN similar to SimpleCNN which uses BarchNormalization and Dropout layers"""
      input_layer = tfkl.Input(shape=input_shape, name='Input')

      x = tfkl.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(input_layer)
      x = tfkl.BatchNormalization()(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=2, strides=2)(x)
      x = tfkl.Dropout(0.2)(x)

      x = tfkl.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(x)
      x = tfkl.BatchNormalization()(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
      x = tfkl.Dropout(0.2)(x)

      x = tfkl.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='he_uniform')(x)
      x = tfkl.BatchNormalization()(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
      x = tfkl.Dropout(0.2)(x)

      x = tfkl.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation='relu', kernel_initializer='he_uniform')(x)
      x = tfkl.BatchNormalization()(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
      x = tfkl.Dropout(0.2)(x)

      x = tfkl.GlobalAveragePooling2D()(x)

      x = tfkl.Dense(units=128, activation='relu', kernel_initializer='he_uniform')(x)
      x = tfkl.BatchNormalization()(x)
      x = tfkl.Activation('relu')(x)
      x = tfkl.Dropout(0.5)(x)

      output_layer = tfkl.Dense(units=output_shape, activation='softmax', kernel_initializer='he_uniform', name='Output')(x)

      model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

      loss = tfk.losses.CategoricalCrossentropy()
      optimizer = tfk.optimizers.Adam(learning_rate)
      metrics = ['accuracy']
      model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

      return model

# %% [markdown]
#  ## Simple_CNN summary

# %%
# Build the model with specified input and output shapes
Simple_CNN = build_model(name = "Simple_CNN")

# Display a summary of the model architecture
Simple_CNN.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(Simple_CNN, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d (Conv2D)                     │ (None, 96, 96, 64)           │         1,792 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation (Activation)             │ (None, 96, 96, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d (MaxPooling2D)        │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_1 (Conv2D)                   │ (None, 48, 48, 128)          │        73,856 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_1 (Activation)           │ (None, 48, 48, 128)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_1 (MaxPooling2D)      │ (None, 24, 24, 128)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_2 (Conv2D)                   │ (None, 24, 24, 256)          │       295,168 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_2 (Activation)           │ (None, 24, 24, 256)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_2 (MaxPooling2D)      │ (None, 12, 12, 256)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_3 (Conv2D)                   │ (None, 10, 10, 512)          │     1,180,160 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_3 (Activation)           │ (None, 10, 10, 512)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_3 (MaxPooling2D)      │ (None, 5, 5, 512)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ global_average_pooling2d            │ (None, 512)                  │             0 │    -    │
# │ (GlobalAveragePooling2D)            │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 128)                  │        65,664 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_4 (Activation)           │ (None, 128)                  │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 8)                    │         1,032 │    Y    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 1,617,672 (6.17 MB)
#  Trainable params: 1,617,672 (6.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
#  ## Normalized_Regularized_CNN summary

# %%
# Build the model with specified input and output shapes
Normalized_Regularized_CNN = build_model(name = "Normalized_Regularized_CNN")

# Display a summary of the model architecture
Normalized_Regularized_CNN.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(Normalized_Regularized_CNN, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 96, 96, 3)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_4 (Conv2D)                   │ (None, 96, 96, 64)           │         1,792 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization                 │ (None, 96, 96, 64)           │           256 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_5 (Activation)           │ (None, 96, 96, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_4 (MaxPooling2D)      │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dropout (Dropout)                   │ (None, 48, 48, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_5 (Conv2D)                   │ (None, 48, 48, 128)          │        73,856 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization_1               │ (None, 48, 48, 128)          │           512 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_6 (Activation)           │ (None, 48, 48, 128)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_5 (MaxPooling2D)      │ (None, 24, 24, 128)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dropout_1 (Dropout)                 │ (None, 24, 24, 128)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_6 (Conv2D)                   │ (None, 24, 24, 256)          │       295,168 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization_2               │ (None, 24, 24, 256)          │         1,024 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_7 (Activation)           │ (None, 24, 24, 256)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_6 (MaxPooling2D)      │ (None, 12, 12, 256)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dropout_2 (Dropout)                 │ (None, 12, 12, 256)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ conv2d_7 (Conv2D)                   │ (None, 10, 10, 512)          │     1,180,160 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization_3               │ (None, 10, 10, 512)          │         2,048 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_8 (Activation)           │ (None, 10, 10, 512)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ max_pooling2d_7 (MaxPooling2D)      │ (None, 5, 5, 512)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dropout_3 (Dropout)                 │ (None, 5, 5, 512)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ global_average_pooling2d_1          │ (None, 512)                  │             0 │    -    │
# │ (GlobalAveragePooling2D)            │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense_1 (Dense)                     │ (None, 128)                  │        65,664 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ batch_normalization_4               │ (None, 128)                  │           512 │    Y    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ activation_9 (Activation)           │ (None, 128)                  │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dropout_4 (Dropout)                 │ (None, 128)                  │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 8)                    │         1,032 │    Y    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 1,622,024 (6.19 MB)
#  Trainable params: 1,619,848 (6.18 MB)
#  Non-trainable params: 2,176 (8.50 KB)

# %% [markdown]
# # Early Stopping

# %%
# Define the patience value for early stopping
patience = 30

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %% [markdown]
# # 🛠️ Train and Save Models

# %% [markdown]
# ## Simple_CNN

# %%
# Train the model with early stopping callback
history = Simple_CNN.fit(
    x=X_train,
    y=y_train,
    batch_size = batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history
# Out:
# Epoch 1/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 100ms/step - accuracy: 0.1918 - loss: 2.2373 - val_accuracy: 0.2805 - val_loss: 1.8901
# Epoch 2/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.3161 - loss: 1.8377 - val_accuracy: 0.3282 - val_loss: 1.7937
# Epoch 3/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.3691 - loss: 1.7316 - val_accuracy: 0.3884 - val_loss: 1.7297
# Epoch 4/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.4473 - loss: 1.6258 - val_accuracy: 0.4804 - val_loss: 1.5482
# Epoch 5/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.4922 - loss: 1.5303 - val_accuracy: 0.5339 - val_loss: 1.4583
# Epoch 6/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.5246 - loss: 1.4638 - val_accuracy: 0.5146 - val_loss: 1.4864
# Epoch 7/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.5545 - loss: 1.4179 - val_accuracy: 0.5723 - val_loss: 1.4018
# Epoch 8/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.5764 - loss: 1.3605 - val_accuracy: 0.5757 - val_loss: 1.3788
# Epoch 9/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.5987 - loss: 1.3053 - val_accuracy: 0.6024 - val_loss: 1.3309
# Epoch 10/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.6170 - loss: 1.2649 - val_accuracy: 0.5949 - val_loss: 1.3254
# Epoch 11/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.6380 - loss: 1.2330 - val_accuracy: 0.6212 - val_loss: 1.2751
# Epoch 12/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.6703 - loss: 1.1717 - val_accuracy: 0.6267 - val_loss: 1.2649
# Epoch 13/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.6746 - loss: 1.1608 - val_accuracy: 0.6334 - val_loss: 1.2750
# Epoch 14/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.6834 - loss: 1.1228 - val_accuracy: 0.6137 - val_loss: 1.2790
# Epoch 15/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.7051 - loss: 1.0710 - val_accuracy: 0.6350 - val_loss: 1.2466
# Epoch 16/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.7237 - loss: 1.0379 - val_accuracy: 0.6367 - val_loss: 1.2583
# Epoch 17/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.7355 - loss: 1.0021 - val_accuracy: 0.6438 - val_loss: 1.2587
# Epoch 18/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.7630 - loss: 0.9521 - val_accuracy: 0.6538 - val_loss: 1.2415
# Epoch 19/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.7749 - loss: 0.9159 - val_accuracy: 0.6267 - val_loss: 1.3029
# Epoch 20/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.7821 - loss: 0.8979 - val_accuracy: 0.6296 - val_loss: 1.3083
# Epoch 21/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.8091 - loss: 0.8320 - val_accuracy: 0.6388 - val_loss: 1.2811
# Epoch 22/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.8158 - loss: 0.8117 - val_accuracy: 0.6484 - val_loss: 1.2973
# Epoch 23/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 0.8345 - loss: 0.7672 - val_accuracy: 0.6300 - val_loss: 1.3186
# Epoch 24/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8530 - loss: 0.7277 - val_accuracy: 0.6380 - val_loss: 1.3079
# Epoch 25/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8592 - loss: 0.7051 - val_accuracy: 0.6430 - val_loss: 1.3113
# Epoch 26/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8721 - loss: 0.6733 - val_accuracy: 0.6342 - val_loss: 1.3563
# Epoch 27/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8743 - loss: 0.6548 - val_accuracy: 0.6292 - val_loss: 1.3927
# Epoch 28/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8829 - loss: 0.6391 - val_accuracy: 0.6325 - val_loss: 1.4043
# Epoch 29/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8750 - loss: 0.6169 - val_accuracy: 0.6359 - val_loss: 1.3529
# Epoch 30/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.8822 - loss: 0.6056 - val_accuracy: 0.6401 - val_loss: 1.4009
# Epoch 31/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8955 - loss: 0.5827 - val_accuracy: 0.6309 - val_loss: 1.3828
# Epoch 32/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8855 - loss: 0.5850 - val_accuracy: 0.6321 - val_loss: 1.3963
# Epoch 33/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 0.8958 - loss: 0.5706 - val_accuracy: 0.6317 - val_loss: 1.4095
# Epoch 34/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8935 - loss: 0.5524 - val_accuracy: 0.6300 - val_loss: 1.4348
# Epoch 35/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8813 - loss: 0.5548 - val_accuracy: 0.6384 - val_loss: 1.3987
# Epoch 36/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8886 - loss: 0.5531 - val_accuracy: 0.6313 - val_loss: 1.4355
# Epoch 37/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8962 - loss: 0.5356 - val_accuracy: 0.6442 - val_loss: 1.4316
# Epoch 38/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8938 - loss: 0.5392 - val_accuracy: 0.6434 - val_loss: 1.4177
# Epoch 39/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8950 - loss: 0.5298 - val_accuracy: 0.6338 - val_loss: 1.4603
# Epoch 40/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.8912 - loss: 0.5227 - val_accuracy: 0.6371 - val_loss: 1.4085
# Epoch 41/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8934 - loss: 0.5284 - val_accuracy: 0.6396 - val_loss: 1.4456
# Epoch 42/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.8905 - loss: 0.5165 - val_accuracy: 0.6267 - val_loss: 1.4558
# Epoch 43/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8963 - loss: 0.5081 - val_accuracy: 0.6371 - val_loss: 1.4434
# Epoch 44/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.8990 - loss: 0.5019 - val_accuracy: 0.6225 - val_loss: 1.5086
# Epoch 45/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.8855 - loss: 0.5157 - val_accuracy: 0.6191 - val_loss: 1.5024
# Epoch 46/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8875 - loss: 0.5086 - val_accuracy: 0.6371 - val_loss: 1.4517
# Epoch 47/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.9010 - loss: 0.5021 - val_accuracy: 0.6375 - val_loss: 1.4575
# Epoch 48/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8902 - loss: 0.4967 - val_accuracy: 0.6405 - val_loss: 1.4983

# %%
# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')
# Out:
# Final validation accuracy: 65.38%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#Print confusion matrix on the validation set
plot_confusion_matrix(Simple_CNN, X_val, y_val)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
Simple_CNN.save('Simple_CNN.keras')
del Simple_CNN

# %% [markdown]
# ## Normalized_Regularized_CNN

# %%
# Train the model with early stopping callback
history = Normalized_Regularized_CNN.fit(
    x=X_train,
    y=y_train,
    batch_size = batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history
# Out:
# Epoch 1/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - accuracy: 0.2472 - loss: 2.2975 - val_accuracy: 0.2044 - val_loss: 2.0684
# Epoch 2/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4083 - loss: 1.7511 - val_accuracy: 0.3023 - val_loss: 2.0289
# Epoch 3/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.4801 - loss: 1.5907 - val_accuracy: 0.3758 - val_loss: 1.9610
# Epoch 4/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.5299 - loss: 1.4896 - val_accuracy: 0.5033 - val_loss: 1.8072
# Epoch 5/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.5403 - loss: 1.4348 - val_accuracy: 0.5322 - val_loss: 1.6453
# Epoch 6/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.5697 - loss: 1.3899 - val_accuracy: 0.5163 - val_loss: 1.6648
# Epoch 7/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.5870 - loss: 1.3515 - val_accuracy: 0.5811 - val_loss: 1.4644
# Epoch 8/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.6117 - loss: 1.3133 - val_accuracy: 0.5840 - val_loss: 1.3790
# Epoch 9/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.6214 - loss: 1.2826 - val_accuracy: 0.4360 - val_loss: 1.5843
# Epoch 10/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.6260 - loss: 1.2697 - val_accuracy: 0.6028 - val_loss: 1.3399
# Epoch 11/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.6314 - loss: 1.2379 - val_accuracy: 0.5970 - val_loss: 1.3883
# Epoch 12/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.6592 - loss: 1.2030 - val_accuracy: 0.5765 - val_loss: 1.4012
# Epoch 13/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.6619 - loss: 1.1862 - val_accuracy: 0.5953 - val_loss: 1.4167
# Epoch 14/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.6645 - loss: 1.1754 - val_accuracy: 0.6200 - val_loss: 1.2858
# Epoch 15/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.6783 - loss: 1.1254 - val_accuracy: 0.5707 - val_loss: 1.4219
# Epoch 16/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 0.6920 - loss: 1.1196 - val_accuracy: 0.6012 - val_loss: 1.3084
# Epoch 17/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.6949 - loss: 1.0933 - val_accuracy: 0.6451 - val_loss: 1.2530
# Epoch 18/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7049 - loss: 1.0732 - val_accuracy: 0.5853 - val_loss: 1.3731
# Epoch 19/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7074 - loss: 1.0556 - val_accuracy: 0.6020 - val_loss: 1.3667
# Epoch 20/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7182 - loss: 1.0346 - val_accuracy: 0.6150 - val_loss: 1.3039
# Epoch 21/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7228 - loss: 1.0114 - val_accuracy: 0.5531 - val_loss: 1.4168
# Epoch 22/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7272 - loss: 0.9823 - val_accuracy: 0.6534 - val_loss: 1.2192
# Epoch 23/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7379 - loss: 0.9615 - val_accuracy: 0.6501 - val_loss: 1.2402
# Epoch 24/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.7381 - loss: 0.9582 - val_accuracy: 0.5690 - val_loss: 1.3759
# Epoch 25/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7419 - loss: 0.9473 - val_accuracy: 0.6488 - val_loss: 1.2126
# Epoch 26/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7580 - loss: 0.9288 - val_accuracy: 0.6702 - val_loss: 1.1730
# Epoch 27/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.7596 - loss: 0.9013 - val_accuracy: 0.6505 - val_loss: 1.2549
# Epoch 28/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.7656 - loss: 0.8817 - val_accuracy: 0.5171 - val_loss: 1.6170
# Epoch 29/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.7699 - loss: 0.8644 - val_accuracy: 0.5464 - val_loss: 1.4473
# Epoch 30/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.7743 - loss: 0.8618 - val_accuracy: 0.6413 - val_loss: 1.2981
# Epoch 31/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.7784 - loss: 0.8277 - val_accuracy: 0.6350 - val_loss: 1.2689
# Epoch 32/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.7737 - loss: 0.8370 - val_accuracy: 0.6271 - val_loss: 1.2842
# Epoch 33/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7796 - loss: 0.8202 - val_accuracy: 0.3186 - val_loss: 3.4914
# Epoch 34/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7816 - loss: 0.7960 - val_accuracy: 0.6601 - val_loss: 1.1868
# Epoch 35/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.7918 - loss: 0.7871 - val_accuracy: 0.6806 - val_loss: 1.2253
# Epoch 36/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.7886 - loss: 0.7766 - val_accuracy: 0.6375 - val_loss: 1.2669
# Epoch 37/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7961 - loss: 0.7621 - val_accuracy: 0.6593 - val_loss: 1.2325
# Epoch 38/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.7909 - loss: 0.7623 - val_accuracy: 0.6513 - val_loss: 1.2277
# Epoch 39/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.7955 - loss: 0.7486 - val_accuracy: 0.4110 - val_loss: 1.8886
# Epoch 40/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.8075 - loss: 0.7373 - val_accuracy: 0.6405 - val_loss: 1.2857
# Epoch 41/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8025 - loss: 0.7397 - val_accuracy: 0.6639 - val_loss: 1.2211
# Epoch 42/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.8081 - loss: 0.7199 - val_accuracy: 0.6401 - val_loss: 1.2489
# Epoch 43/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.8187 - loss: 0.7093 - val_accuracy: 0.6208 - val_loss: 1.3622
# Epoch 44/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.8124 - loss: 0.6976 - val_accuracy: 0.6639 - val_loss: 1.1988
# Epoch 45/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8162 - loss: 0.6952 - val_accuracy: 0.5447 - val_loss: 1.5442
# Epoch 46/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8171 - loss: 0.6874 - val_accuracy: 0.6488 - val_loss: 1.2735
# Epoch 47/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.8070 - loss: 0.6839 - val_accuracy: 0.5452 - val_loss: 1.7315
# Epoch 48/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8147 - loss: 0.6797 - val_accuracy: 0.6639 - val_loss: 1.2218
# Epoch 49/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.8125 - loss: 0.6877 - val_accuracy: 0.6651 - val_loss: 1.2553
# Epoch 50/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.8173 - loss: 0.6739 - val_accuracy: 0.6601 - val_loss: 1.2469
# Epoch 51/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.8245 - loss: 0.6642 - val_accuracy: 0.6509 - val_loss: 1.2373
# Epoch 52/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.8243 - loss: 0.6562 - val_accuracy: 0.6221 - val_loss: 1.4035
# Epoch 53/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.8275 - loss: 0.6486 - val_accuracy: 0.6702 - val_loss: 1.2116
# Epoch 54/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.8229 - loss: 0.6456 - val_accuracy: 0.6459 - val_loss: 1.3435
# Epoch 55/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.8250 - loss: 0.6402 - val_accuracy: 0.3700 - val_loss: 2.5629
# Epoch 56/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.8261 - loss: 0.6417 - val_accuracy: 0.6221 - val_loss: 1.3812
# Epoch 57/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.8200 - loss: 0.6452 - val_accuracy: 0.6626 - val_loss: 1.2237
# Epoch 58/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8216 - loss: 0.6248 - val_accuracy: 0.5740 - val_loss: 1.5044
# Epoch 59/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.8281 - loss: 0.6295 - val_accuracy: 0.4578 - val_loss: 2.5032
# Epoch 60/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.8257 - loss: 0.6200 - val_accuracy: 0.6522 - val_loss: 1.3103
# Epoch 61/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.8294 - loss: 0.6244 - val_accuracy: 0.2968 - val_loss: 2.8482
# Epoch 62/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.8206 - loss: 0.6140 - val_accuracy: 0.5594 - val_loss: 1.8132
# Epoch 63/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.8297 - loss: 0.6165 - val_accuracy: 0.6551 - val_loss: 1.2835
# Epoch 64/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.8203 - loss: 0.6146 - val_accuracy: 0.6045 - val_loss: 1.5394
# Epoch 65/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.8213 - loss: 0.6135 - val_accuracy: 0.6693 - val_loss: 1.3316

# %%
# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')
# Out:
# Final validation accuracy: 68.06%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#Print confusion matrix on the validation set
plot_confusion_matrix(Normalized_Regularized_CNN, X_val, y_val)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step

# %%
Normalized_Regularized_CNN.save('Normalized_Regularized_CNN.keras')
del Normalized_Regularized_CNN

# %% [markdown]
# # 📊 Prepare Your Submission

# %%
#source = "Simple_CNN.keras"
source = "Normalized_Regularized_CNN.keras"
destination = "weights.keras"

# Take a source an call it "weights.keras"
shutil.copy(source, destination)
# Out:
# 'weights.keras'

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Load the model from the weights.keras file.
        """
        self.neural_network = tfk.models.load_model('weights.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,).

        We check and normalize the image in X, extracting the prediction that the model does.
        """
        # Normalizzare le immagini (applicare la divisione per 255)
        if X.max() > 1.0:  # If max value is greater than 1, assume the range is [0, 255]
            X = X / 255.0

        # Fare la previsione con il modello
        preds = self.neural_network.predict(X)

        # Se l'output è in formato one-hot (shape = 2D), prendere l'argmax per ottenere le classi
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)

        return preds
# Out:
# Overwriting model.py

# %%
from datetime import datetime
filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py weights.keras

from google.colab import files
files.download(filename)
