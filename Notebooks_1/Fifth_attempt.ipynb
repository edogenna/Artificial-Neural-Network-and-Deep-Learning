# %% [markdown]
# # Import Libraries

# %%
# %%writefile requirements.txt
# tensorflow==2.17.0
# keras==3.4.1
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt
# !pip install keras-cv
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: tensorflow==2.17.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: keras==3.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.62.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras==3.4.1->-r requirements.txt (line 2)) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras==3.4.1->-r requirements.txt (line 2)) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras==3.4.1->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras==3.4.1->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras==3.4.1->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras==3.4.1->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: keras-cv in /opt/conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from keras-cv) (21.3)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from keras-cv) (2024.5.15)
# Requirement already satisfied: tensorflow-datasets in /opt/conda/lib/python3.10/site-packages (from keras-cv) (4.9.6)
# Requirement already satisfied: keras-core in /opt/conda/lib/python3.10/site-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in /opt/conda/lib/python3.10/site-packages (from keras-cv) (0.3.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from kagglehub->keras-cv) (4.66.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras-core->keras-cv) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras-core->keras-cv) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras-core->keras-cv) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-core->keras-cv) (3.11.0)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.10/site-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->keras-cv) (3.1.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (3.20.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (5.9.3)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (16.1.0)
# Requirement already satisfied: simple-parsing in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (0.14.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (2.4.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.7.0)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (4.12.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.6.1)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.0)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras-cv) (2024.8.30)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras-core->keras-cv) (2.18.0)
# Requirement already satisfied: docstring-parser~=0.15 in /opt/conda/lib/python3.10/site-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.10/site-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.63.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)

# %%
import keras_cv
import numpy as np
import os
import tensorflow as tf
import keras as tfk
from keras.layers import Input, Dense, Dropout, Lambda
from keras import layers as tfkl
from keras.utils import to_categorical
from collections import Counter
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import sklearn as scikit_learn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

seed = 42

# %% [markdown]
# ## Help Functions

# %%
def plot_confusion_matrix(model, X_test, y_test):
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)

    if y_test.ndim > 1:
        y_test = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_test, y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(len(cm)))
    disp.plot(cmap='viridis', xticks_rotation='vertical')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# # Load the Data

# %%
#This time we work on Kagge
#Load the dataset from the .npz file and take "images" and "labels"
data = np.load('/kaggle/input/dataset/training_set_without_outlier.npz')

images = data['images']
labels = data['labels']
print(f'Images shape: {images.shape}')
print(f'Labels shape: {labels.shape}')

#Initial shuffle of the data
indices = np.random.permutation(len(images))
shuffled_images = images[indices]
shuffled_labels = labels[indices]


#Free some memory
del data
del images
del labels
del indices
# Out:
# Images shape: (11959, 96, 96, 3)
# Labels shape: (11959, 1)

# %% [markdown]
# # Process Data

# %%
#Normalization of images and categorical format for labels
normalized_images = shuffled_images / 255.0
categorical_labels = to_categorical(shuffled_labels).astype('float32')

# %%
# Split data into Training set and Validation set
X_train, X_val, y_train, y_val = train_test_split(normalized_images, categorical_labels, test_size=0.2, stratify=categorical_labels)

print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (9567, 96, 96, 3)
# (2392, 96, 96, 3)
# (9567, 8)
# (2392, 8)

# %% [markdown]
# # Augmentation

# %%
# New way to apply augmentations
data_augmentation = tfk.Sequential(
[
    keras_cv.layers.RandAugment(
        value_range=(0.0, 1.0),
        augmentations_per_image=3,
        magnitude_stddev=0.3,
        rate=0.5
    )
])

# %%
#Try to augment a portion of the X_train images
image_portion = X_train[:9]
image_portion = data_augmentation(image_portion)

#Plot the augmentations
plt.figure(figsize=(10, 10))
for i in range(9):
   plt.subplot(3, 3, i + 1)
   plt.imshow(image_portion[i])
   plt.axis("off")
plt.show()

# %%
#Convert the data into a more suitable format that speeds up the augmentation a lot
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(512)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(512)

# %%
#wrapper fucntion for the augmentation
def augment_images(image, label):
    image = data_augmentation(image)  # Apply data augmentation to the image
    return image, label  # Return the augmented image and the unchanged label

# Apply the mapping to both Train and Validation sets
train_dataset = train_dataset.map(augment_images, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

val_dataset = val_dataset.map(augment_images, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.prefetch(tf.data.AUTOTUNE)

# %%
# Reconvert the Training and Validation set into numpy arrays
X_train, y_train = [], []
for batch in train_dataset:
    images = batch[0].numpy()
    labels = batch[1].numpy()
    X_train.append(images)
    y_train.append(labels)
X_train = np.concatenate(X_train, axis=0)
y_train = np.concatenate(y_train, axis=0)

del train_dataset

# Convert validation dataset to numpy arrays
X_val, y_val = [], []
for batch in val_dataset:
    images = batch[0].numpy()
    labels = batch[1].numpy()
    X_val.append(images)
    y_val.append(labels)
X_val = np.concatenate(X_val, axis=0)
y_val = np.concatenate(y_val, axis=0)

del val_dataset

# %% [markdown]
# # Define Model

# %%
input_shape = (96, 96, 3)
output_shape = 8
learning_rate = 0.001
batch_size = 64
epochs = 300

# Slightly change to the model filters w.r.t the previous notebook (from Normalized_Regularized_CNN)
# to reduce the number of parameters
def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=learning_rate
):

    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(input_layer)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)
    x = tfkl.MaxPooling2D(pool_size=2, strides=3)(x)
    x = tfkl.Dropout(0.2)(x)

    x = tfkl.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)
    x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
    x = tfkl.Dropout(0.2)(x)

    x = tfkl.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_initializer='he_uniform')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)
    x = tfkl.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
    x = tfkl.Dropout(0.2)(x)

    x = tfkl.GlobalAveragePooling2D()(x)

    x = tfkl.Dense(units=128, kernel_initializer='he_uniform')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)
    x = tfkl.Dropout(0.5)(x)

    output_layer = tfkl.Dense(units=output_shape, activation='softmax', kernel_initializer='he_uniform', name='Output')(x)

    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    loss = tfk.losses.CategoricalCrossentropy()
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    return model

# %%
# Build the model with specified input and output shapes
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ Input (InputLayer)          │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2d_4 (Conv2D)           │ (None, 96, 96, 64)    │      1,792 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ batch_normalization_4       │ (None, 96, 96, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ activation_4 (Activation)   │ (None, 96, 96, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ max_pooling2d_3             │ (None, 32, 32, 64)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout_2 (Dropout)         │ (None, 32, 32, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2d_5 (Conv2D)           │ (None, 32, 32, 128)   │     73,856 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ batch_normalization_5       │ (None, 32, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ activation_5 (Activation)   │ (None, 32, 32, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2d_6 (Conv2D)           │ (None, 32, 32, 256)   │    295,168 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ batch_normalization_6       │ (None, 32, 32, 256)   │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ activation_6 (Activation)   │ (None, 32, 32, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ max_pooling2d_4             │ (None, 16, 16, 256)   │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout_3 (Dropout)         │ (None, 16, 16, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2d_7 (Conv2D)           │ (None, 16, 16, 256)   │    590,080 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ batch_normalization_7       │ (None, 16, 16, 256)   │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ activation_7 (Activation)   │ (None, 16, 16, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ max_pooling2d_5             │ (None, 8, 8, 256)     │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout_4 (Dropout)         │ (None, 8, 8, 256)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 256)           │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 128)           │     32,896 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ batch_normalization_8       │ (None, 128)           │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ activation_8 (Activation)   │ (None, 128)           │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dropout_5 (Dropout)         │ (None, 128)           │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ Output (Dense)              │ (None, 8)             │      1,032 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 998,152 (3.81 MB)
#  Trainable params: 996,488 (3.80 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %% [markdown]
# # Early Stopping

# %%
# Define the patience value for early stopping
patience = 20

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %% [markdown]
# # Train Model

# %%
# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size = batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')
# Out:
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732021510.104127     108 service.cc:146] XLA service 0x5c9e213ecbf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732021510.104190     108 service.cc:154]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   5/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.1693 - loss: 2.5929
# I0000 00:00:1732021517.002433     108 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 82ms/step - accuracy: 0.3297 - loss: 1.9791 - val_accuracy: 0.3512 - val_loss: 2.2801
# Epoch 2/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.5303 - loss: 1.2742 - val_accuracy: 0.3344 - val_loss: 2.2577
# Epoch 3/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.6107 - loss: 1.0803 - val_accuracy: 0.6120 - val_loss: 1.0585
# Epoch 4/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.6455 - loss: 0.9888 - val_accuracy: 0.5707 - val_loss: 1.2136
# Epoch 5/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.6784 - loss: 0.8832 - val_accuracy: 0.5723 - val_loss: 1.2283
# Epoch 6/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7068 - loss: 0.8292 - val_accuracy: 0.6601 - val_loss: 0.9434
# Epoch 7/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7270 - loss: 0.7698 - val_accuracy: 0.6622 - val_loss: 0.9893
# Epoch 8/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7423 - loss: 0.7395 - val_accuracy: 0.7069 - val_loss: 0.8144
# Epoch 9/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7689 - loss: 0.6726 - val_accuracy: 0.7471 - val_loss: 0.7035
# Epoch 10/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7701 - loss: 0.6569 - val_accuracy: 0.7308 - val_loss: 0.7604
# Epoch 11/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7836 - loss: 0.6291 - val_accuracy: 0.4987 - val_loss: 2.0051
# Epoch 12/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7934 - loss: 0.5849 - val_accuracy: 0.7358 - val_loss: 0.7669
# Epoch 13/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8062 - loss: 0.5715 - val_accuracy: 0.7997 - val_loss: 0.6047
# Epoch 14/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8202 - loss: 0.5238 - val_accuracy: 0.8294 - val_loss: 0.4876
# Epoch 15/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8344 - loss: 0.4888 - val_accuracy: 0.7651 - val_loss: 0.7543
# Epoch 16/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8309 - loss: 0.4836 - val_accuracy: 0.7830 - val_loss: 0.6270
# Epoch 17/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8493 - loss: 0.4615 - val_accuracy: 0.7625 - val_loss: 0.7045
# Epoch 18/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8421 - loss: 0.4462 - val_accuracy: 0.7893 - val_loss: 0.5858
# Epoch 19/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8518 - loss: 0.4317 - val_accuracy: 0.7128 - val_loss: 1.0024
# Epoch 20/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8501 - loss: 0.4188 - val_accuracy: 0.7458 - val_loss: 0.8303
# Epoch 21/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8588 - loss: 0.4002 - val_accuracy: 0.4620 - val_loss: 2.0416
# Epoch 22/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8757 - loss: 0.3750 - val_accuracy: 0.7425 - val_loss: 0.9046
# Epoch 23/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8748 - loss: 0.3505 - val_accuracy: 0.8424 - val_loss: 0.4942
# Epoch 24/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8822 - loss: 0.3571 - val_accuracy: 0.7839 - val_loss: 0.6698
# Epoch 25/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8750 - loss: 0.3542 - val_accuracy: 0.8512 - val_loss: 0.4452
# Epoch 26/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8931 - loss: 0.3072 - val_accuracy: 0.8357 - val_loss: 0.5072
# Epoch 27/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8794 - loss: 0.3352 - val_accuracy: 0.8207 - val_loss: 0.5620
# Epoch 28/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8996 - loss: 0.3070 - val_accuracy: 0.8236 - val_loss: 0.5185
# Epoch 29/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8814 - loss: 0.3331 - val_accuracy: 0.8445 - val_loss: 0.4387
# Epoch 30/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8874 - loss: 0.3278 - val_accuracy: 0.7947 - val_loss: 0.6229
# Epoch 31/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9041 - loss: 0.2887 - val_accuracy: 0.8052 - val_loss: 0.6654
# Epoch 32/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9106 - loss: 0.2619 - val_accuracy: 0.8294 - val_loss: 0.5797
# Epoch 33/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9110 - loss: 0.2564 - val_accuracy: 0.7943 - val_loss: 0.7121
# Epoch 34/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9083 - loss: 0.2644 - val_accuracy: 0.6819 - val_loss: 1.0441
# Epoch 35/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9194 - loss: 0.2282 - val_accuracy: 0.8240 - val_loss: 0.5581
# Epoch 36/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9171 - loss: 0.2336 - val_accuracy: 0.3967 - val_loss: 5.9302
# Epoch 37/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9098 - loss: 0.2453 - val_accuracy: 0.8324 - val_loss: 0.6157
# Epoch 38/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9276 - loss: 0.2158 - val_accuracy: 0.8533 - val_loss: 0.4529
# Epoch 39/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9305 - loss: 0.2069 - val_accuracy: 0.8579 - val_loss: 0.4767
# Epoch 40/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9183 - loss: 0.2383 - val_accuracy: 0.6898 - val_loss: 1.1831
# Epoch 41/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9360 - loss: 0.1882 - val_accuracy: 0.5786 - val_loss: 2.6931
# Epoch 42/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9293 - loss: 0.1968 - val_accuracy: 0.8190 - val_loss: 0.5913
# Epoch 43/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9405 - loss: 0.1791 - val_accuracy: 0.8190 - val_loss: 0.5825
# Epoch 44/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9307 - loss: 0.2050 - val_accuracy: 0.8273 - val_loss: 0.5991
# Epoch 45/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9402 - loss: 0.1731 - val_accuracy: 0.8424 - val_loss: 0.5444
# Epoch 46/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9418 - loss: 0.1638 - val_accuracy: 0.8733 - val_loss: 0.4208
# Epoch 47/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9441 - loss: 0.1636 - val_accuracy: 0.8332 - val_loss: 0.5125
# Epoch 48/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9377 - loss: 0.1681 - val_accuracy: 0.8591 - val_loss: 0.4663
# Epoch 49/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9462 - loss: 0.1488 - val_accuracy: 0.8570 - val_loss: 0.5509
# Epoch 50/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9488 - loss: 0.1442 - val_accuracy: 0.8574 - val_loss: 0.4459
# Epoch 51/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9439 - loss: 0.1702 - val_accuracy: 0.8796 - val_loss: 0.4406
# Epoch 52/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9488 - loss: 0.1468 - val_accuracy: 0.8428 - val_loss: 0.5891
# Epoch 53/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9536 - loss: 0.1355 - val_accuracy: 0.8867 - val_loss: 0.4492
# Epoch 54/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9539 - loss: 0.1386 - val_accuracy: 0.8131 - val_loss: 0.8437
# Epoch 55/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9514 - loss: 0.1288 - val_accuracy: 0.8633 - val_loss: 0.5770
# Epoch 56/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9551 - loss: 0.1225 - val_accuracy: 0.8269 - val_loss: 0.6469
# Epoch 57/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9608 - loss: 0.1111 - val_accuracy: 0.8215 - val_loss: 0.8242
# Epoch 58/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9591 - loss: 0.1147 - val_accuracy: 0.6237 - val_loss: 2.9476
# Epoch 59/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9593 - loss: 0.1177 - val_accuracy: 0.8671 - val_loss: 0.5034
# Epoch 60/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9617 - loss: 0.1151 - val_accuracy: 0.8545 - val_loss: 0.4951
# Epoch 61/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9667 - loss: 0.0970 - val_accuracy: 0.8817 - val_loss: 0.4280
# Epoch 62/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9691 - loss: 0.0912 - val_accuracy: 0.8508 - val_loss: 0.5770
# Epoch 63/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9677 - loss: 0.0988 - val_accuracy: 0.8541 - val_loss: 0.6853
# Epoch 64/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9645 - loss: 0.1008 - val_accuracy: 0.7726 - val_loss: 1.1984
# Epoch 65/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9682 - loss: 0.0902 - val_accuracy: 0.8834 - val_loss: 0.4495
# Epoch 66/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9707 - loss: 0.0955 - val_accuracy: 0.8742 - val_loss: 0.5071
# Epoch 67/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9742 - loss: 0.0784 - val_accuracy: 0.8888 - val_loss: 0.4673
# Epoch 68/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9698 - loss: 0.0881 - val_accuracy: 0.7408 - val_loss: 1.1851
# Epoch 69/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9697 - loss: 0.0909 - val_accuracy: 0.8654 - val_loss: 0.5843
# Epoch 70/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9741 - loss: 0.0801 - val_accuracy: 0.8599 - val_loss: 0.5721
# Epoch 71/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9732 - loss: 0.0840 - val_accuracy: 0.8395 - val_loss: 0.7184
# Epoch 72/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9722 - loss: 0.0815 - val_accuracy: 0.8186 - val_loss: 0.8098
# Epoch 73/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9708 - loss: 0.0934 - val_accuracy: 0.8717 - val_loss: 0.5743
# Epoch 74/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9793 - loss: 0.0667 - val_accuracy: 0.4360 - val_loss: 4.7759
# Epoch 75/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9716 - loss: 0.0842 - val_accuracy: 0.8123 - val_loss: 0.7660
# Epoch 76/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9716 - loss: 0.0849 - val_accuracy: 0.8976 - val_loss: 0.4501
# Epoch 77/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9780 - loss: 0.0681 - val_accuracy: 0.8370 - val_loss: 0.8331
# Epoch 78/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9748 - loss: 0.0819 - val_accuracy: 0.8976 - val_loss: 0.4079
# Epoch 79/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9725 - loss: 0.0822 - val_accuracy: 0.7040 - val_loss: 1.3635
# Epoch 80/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9760 - loss: 0.0741 - val_accuracy: 0.8524 - val_loss: 0.5701
# Epoch 81/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9769 - loss: 0.0687 - val_accuracy: 0.7128 - val_loss: 1.6799
# Epoch 82/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9796 - loss: 0.0661 - val_accuracy: 0.8733 - val_loss: 0.7315
# Epoch 83/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9816 - loss: 0.0534 - val_accuracy: 0.8804 - val_loss: 0.5394
# Epoch 84/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9810 - loss: 0.0588 - val_accuracy: 0.8344 - val_loss: 0.8555
# Epoch 85/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9795 - loss: 0.0637 - val_accuracy: 0.8332 - val_loss: 0.7106
# Epoch 86/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9778 - loss: 0.0612 - val_accuracy: 0.8612 - val_loss: 0.5943
# Epoch 87/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9814 - loss: 0.0572 - val_accuracy: 0.8633 - val_loss: 0.5958
# Epoch 88/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9771 - loss: 0.0667 - val_accuracy: 0.8788 - val_loss: 0.5995
# Epoch 89/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9842 - loss: 0.0548 - val_accuracy: 0.8712 - val_loss: 0.6265
# Epoch 90/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9785 - loss: 0.0622 - val_accuracy: 0.7078 - val_loss: 1.6539
# Epoch 91/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9774 - loss: 0.0638 - val_accuracy: 0.9009 - val_loss: 0.4879
# Epoch 92/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9837 - loss: 0.0509 - val_accuracy: 0.8537 - val_loss: 0.6941
# Epoch 93/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9834 - loss: 0.0509 - val_accuracy: 0.8834 - val_loss: 0.5053
# Epoch 94/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9849 - loss: 0.0461 - val_accuracy: 0.8838 - val_loss: 0.6480
# Epoch 95/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9847 - loss: 0.0516 - val_accuracy: 0.8512 - val_loss: 0.7512
# Epoch 96/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9788 - loss: 0.0560 - val_accuracy: 0.8963 - val_loss: 0.5076
# Epoch 97/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9862 - loss: 0.0480 - val_accuracy: 0.7809 - val_loss: 1.1854
# Epoch 98/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9824 - loss: 0.0564 - val_accuracy: 0.8687 - val_loss: 0.6443
# Epoch 99/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9823 - loss: 0.0560 - val_accuracy: 0.8988 - val_loss: 0.4503
# Epoch 100/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9863 - loss: 0.0441 - val_accuracy: 0.8654 - val_loss: 0.7300
# Epoch 101/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9789 - loss: 0.0559 - val_accuracy: 0.8654 - val_loss: 0.7077
# Epoch 102/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9861 - loss: 0.0453 - val_accuracy: 0.9118 - val_loss: 0.4083
# Epoch 103/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9858 - loss: 0.0444 - val_accuracy: 0.7630 - val_loss: 1.1300
# Epoch 104/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9851 - loss: 0.0453 - val_accuracy: 0.8675 - val_loss: 0.7217
# Epoch 105/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9833 - loss: 0.0449 - val_accuracy: 0.8771 - val_loss: 0.6174
# Epoch 106/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9868 - loss: 0.0431 - val_accuracy: 0.8654 - val_loss: 0.6928
# Epoch 107/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9886 - loss: 0.0345 - val_accuracy: 0.8278 - val_loss: 1.0324
# Epoch 108/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9859 - loss: 0.0430 - val_accuracy: 0.8696 - val_loss: 0.7273
# Epoch 109/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9852 - loss: 0.0440 - val_accuracy: 0.8742 - val_loss: 0.6098
# Epoch 110/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9879 - loss: 0.0354 - val_accuracy: 0.8712 - val_loss: 0.7253
# Epoch 111/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9901 - loss: 0.0334 - val_accuracy: 0.8934 - val_loss: 0.5528
# Epoch 112/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9819 - loss: 0.0553 - val_accuracy: 0.7262 - val_loss: 1.7698
# Epoch 113/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9849 - loss: 0.0463 - val_accuracy: 0.8478 - val_loss: 0.7566
# Epoch 114/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9900 - loss: 0.0324 - val_accuracy: 0.8783 - val_loss: 0.6985
# Epoch 115/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9778 - loss: 0.0690 - val_accuracy: 0.7086 - val_loss: 1.2981
# Epoch 116/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9832 - loss: 0.0576 - val_accuracy: 0.8884 - val_loss: 0.5574
# Epoch 117/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9851 - loss: 0.0422 - val_accuracy: 0.8972 - val_loss: 0.5079
# Epoch 118/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9900 - loss: 0.0287 - val_accuracy: 0.7634 - val_loss: 1.3650
# Epoch 119/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9866 - loss: 0.0389 - val_accuracy: 0.9005 - val_loss: 0.5769
# Epoch 120/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9900 - loss: 0.0318 - val_accuracy: 0.8763 - val_loss: 0.6776
# Epoch 121/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9901 - loss: 0.0296 - val_accuracy: 0.8997 - val_loss: 0.4914
# Epoch 122/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9919 - loss: 0.0273 - val_accuracy: 0.8528 - val_loss: 0.8624
# Final validation accuracy: 91.18%

# %%
# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')
# Out:
# Final validation accuracy: 91.18%

# %%
# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#Print confusion matrix on the validation set
plot_confusion_matrix(model, X_val, y_val)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step

# %%
model.save('weights.keras')
del model

# %% [markdown]
# # 📊 Prepare Your Submission

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.

        The following is an example loading the weights of a pre-trained
        model.
        """
        self.neural_network = tfk.models.load_model('weights.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must not be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        # Normalizzare le immagini (applicare la divisione per 255)
        if X.max() > 1.0:  # If max value is greater than 1, assume the range is [0, 255]
            X = X / 255.0


        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
           preds = np.argmax(preds, axis=1)
        return preds

# %%
from datetime import datetime
filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py weights.keras
